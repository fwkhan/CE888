# %% [markdown]
# <a href="https://colab.research.google.com/github/fwkhan/CE888/blob/main/movies_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
item_features_df = pd.read_excel('movies_latent_factors.xlsx', sheet_name=0)
df_0=item_features_df

# %%
# In the movies dataset, what's the loading (i.e., value) of Factor6 for the movie with ID=607?
item_features_df[item_features_df['Movie ID']==607].Factor6
# Out:
# 52    0.871926
# Name: Factor6, dtype: float64

# %%
lst = [955,
       568,
       597,
       114,
       63]
for i in lst:
    print(item_features_df[item_features_df['Movie ID']==i].Factor14)
# Out:
# 72    1.547867
# Name: Factor14, dtype: float64
# 44   -0.465172
# Name: Factor14, dtype: float64
# 47    2.215933
# Name: Factor14, dtype: float64
# 13    0.662535
# Name: Factor14, dtype: float64
# 7   -0.229462
# Name: Factor14, dtype: float64

# %%
item_features_df
# Out:
#     Movie ID  ...  Factor15
# 0         11  ... -0.248806
# 1         12  ...  1.274993
# 2         13  ... -0.419092
# 3         14  ... -0.681191
# 4         22  ... -2.292566
# ..       ...  ...       ...
# 95      9806  ...  1.017861
# 96     10020  ... -0.487076
# 97     36657  ...  0.067790
# 98     36658  ... -0.288130
# 99     36955  ... -0.022599
#
# [100 rows x 17 columns]

# %%
from IPython.display import display
lst = ['Pretty Woman (1990)',
       'Requiem for a Dream (2000)',
       'The Sixth Sense (1999)',
       'Independence Day (a.k.a. ID4) (1996)',
       'The Lion King (1994)',
      'Titanic (1997)',
      'Spider-Man (2002)']
for i in lst:
    display(df_0[df_0['Title']==i]['Factor11'])
# Out:
# 13    0.061864
# Name: Factor11, dtype: float64
# 55    0.469671
# Name: Factor11, dtype: float64
# 60    0.504873
# Name: Factor11, dtype: float64
# 49    0.652717
# Name: Factor11, dtype: float64
# 91   -0.804286
# Name: Factor11, dtype: float64
# 47   -0.589441
# Name: Factor11, dtype: float64
# 42   -1.78801
# Name: Factor11, dtype: float64

# %%
user_features_df = pd.read_excel('movies_latent_factors.xlsx', sheet_name=1)
user_features_df
# Out:
#     User   Factor1   Factor2   Factor3  ...  Factor12  Factor13  Factor14  Factor15
# 0   4768 -0.204024  0.161079 -0.090447  ...  0.355404  0.007108 -0.118663 -0.039125
# 1    156 -0.189652 -0.178979 -0.091490  ... -0.048606  0.045916  0.113671  0.179873
# 2   5323 -0.115308 -0.090886 -0.053129  ... -0.019460  0.108372  0.054471 -0.109552
# 3    174 -0.227462 -0.272532 -0.017231  ... -0.082396  0.036767 -0.165438  0.050692
# 4   4529 -0.014616 -0.102218 -0.107935  ... -0.132836 -0.039897  0.129063  0.102669
# 5    783 -0.020301 -0.031919 -0.036955  ...  0.059725 -0.021647  0.039873 -0.061857
# 6   3878 -0.091462  0.215879 -0.180453  ...  0.214467  0.189250  0.065990  0.102776
# 7    768  0.000819 -0.009229 -0.019228  ... -0.010051 -0.002108  0.043223 -0.006670
# 8   4469 -0.030528 -0.011537 -0.042822  ...  0.010926  0.024400  0.005318 -0.007983
# 9   1882 -0.083093 -0.029160  0.013748  ... -0.113364 -0.021325  0.181508  0.022357
# ...

# %%
latent_user_preferences = user_features_df.drop(['User'],axis = 1)
latent_user_preferences.shape #,'user_id','key'
# Out:
# (25, 15)

# %%
latent_item_features = item_features_df.drop(['Movie ID', 'Title'],axis = 1)
latent_item_features.shape   # ,'item_id','key'
# Out:
# (100, 15)

# %%
predictions = latent_user_preferences.dot(latent_item_features.T)

# %%
predictions.columns= item_features_df['Movie ID'].values

# %%
predictions.index = user_features_df.User.values

# %%
predictions
# Out:
#          11        12        13     ...     36657     36658     36955
# 4768  0.389174  0.191449  0.766364  ... -0.395129 -0.522412  0.097010
# 156   0.883069  0.319496  0.396485  ... -0.259385 -0.455462 -0.113381
# 5323  0.214068  0.154537  0.261073  ... -0.083633 -0.163929 -0.199840
# 174  -0.139366  0.129855  1.212876  ...  0.138995  0.003095 -0.524709
# 4529 -0.038172  0.866052 -0.285316  ...  0.079577  0.070540 -0.357920
# 783   0.063515  0.168541  0.170626  ... -0.161995 -0.125955 -0.183417
# 3878  0.619344  0.396214  0.205784  ... -0.376227 -0.555636  0.193396
# 768   0.028389  0.017066 -0.025851  ... -0.098649 -0.085649 -0.006351
# 4469  0.033540 -0.066459  0.170744  ... -0.052109 -0.057458 -0.076232
# 1882  0.220284  0.366293 -0.212080  ... -0.105606 -0.104062 -0.445656
# 4997 -1.218669  0.253885  1.916883  ...  0.031380 -0.000738 -1.247069
# 2067 -0.239497  0.321743  0.828942  ... -0.073809 -0.200035  0.009083
# ...

# %%
# predict the rating that the user with ID 174 will give to the movie with ID 1894
# predictions[movieID][user]
predictions[1894][174]
# Out:
# 0.4999822665181686

# %%
# predict the rating that the user with ID 1882 will give to the movie with ID 1422.
predictions[1422][1882]
# Out:
# 0.07348033081037716

# %%
item = [238,
       
       
       155,
       ]
        

for i in item:
    display(predictions[predictions.index==5323][i])
# Out:
# 5323    0.694714
# Name: 238, dtype: float64
# 5323    0.759871
# Name: 155, dtype: float64

# %%
item = [
       85,
       
       
       105]
        

for i in item:
    display(predictions[predictions.index==4768][i])
# Out:
# 4768    1.18811
# Name: 85, dtype: float64
# 4768    1.075866
# Name: 105, dtype: float64

# %%
predictions[predictions.index==2665][604]
# Out:
# 2665    0.707718
# Name: 604, dtype: float64

# %%
predictions.columns
# Out:
# Int64Index([   11,    12,    13,    14,    22,    24,    38,    63,    77,
#                85,    98,   105,   107,   114,   120,   121,   122,   134,
#               141,   146,   153,   155,   161,   180,   187,   194,   197,
#               238,   243,   268,   272,   274,   275,   278,   280,   329,
#               393,   414,   424,   453,   462,   550,   557,   558,   568,
#               581,   585,   597,   601,   602,   603,   604,   607,   629,
#               640,   641,   664,   671,   672,   680,   745,   752,   786,
#               788,   807,   808,   809,   812,   854,   857,   862,   954,
#               955,  1422,  1572,  1597,  1637,  1891,  1892,  1894,  1900,
#              2024,  2164,  2501,  2502,  3049,  4327,  5503,  7443,  8358,
#              8467,  8587,  9331,  9741,  9802,  9806, 10020, 36657, 36658,
#             36955],
#            dtype='int64')

# %%
item = [122,
        121]

for i in item:
    display(predictions[predictions.index==174][i])
# Out:
# 174    1.891704
# Name: 122, dtype: float64
# 174    1.892477
# Name: 121, dtype: float64
